# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanda0975/MT/blob/main/Plebiscito_88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup

# %%
#Resultado final es una variable binaria por comuna donde toma el valor de 1: ganadora opción "SI", 0: cualquier otra opción

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %%
df = pd.read_excel("https://github.com/Amanda0975/MT/raw/main/raw/Plebiscito88_raw.xlsx")

# %% [markdown]
# ##Descripción data

# %%
display(df)
# Out:
#        region  region_id         comuna       NO       SI BLANCO NULOS  \
# 0    Tarapacá          1  Alto Hospicio      NaN      NaN    NaN   NaN
# 1    Tarapacá          1         Camiña    191.0    519.0      4    13
# 2    Tarapacá          1       Colchane    125.0    554.0      9    33
# 3    Tarapacá          1          Huara    305.0    531.0     47    54
# 4    Tarapacá          1        Iquique  39582.0  33354.0    828    51
# ..        ...        ...            ...      ...      ...    ...   ...
# 341     Ñuble         16     San Fabián    675.0   1644.0     29    14
# 342     Ñuble         16    San Ignacio   2731.0   5587.0    115    85
# 343     Ñuble         16    San Nicolás   1929.0   2669.0     38    64
# 344     Ñuble         16       Treguaco    982.0   1852.0     53    53
# 345     Ñuble         16         Yungay   3569.0   5110.0    112   126
#
#      resultado
# 0            0
# 1            1
# 2            1
# 3            1
# 4            0
# ..         ...
# ...

# %%
#Filtrar database
df1=df.drop(columns=["NO", "region", "SI", "BLANCO", "NULOS"])

# %%
df1.nunique()
# Out:
# region_id     16
# comuna       346
# resultado      2
# dtype: int64

# %%
(df1['resultado'] == 1).sum()
# Out:
# 188

# %%
(df1['resultado'] == 0).sum()
# Out:
# 158

# %%
#Exportar .csv
df1.to_csv('Plebiscito88.csv', index=False)

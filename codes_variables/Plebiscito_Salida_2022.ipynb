# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanda0975/MT/blob/main/Plebiscito_Salida_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup

# %%
from IPython.display import display
import numpy as np
import pandas as pd

#Importar database desde github (Resultados eleccionarios)
df = pd.read_csv("https://github.com/cnavarreteliz/atlas-elections-data/raw/master/data_output/Chile/2022_plebiscite_polling_station.csv.gz", compression='gzip')
df_location = pd.read_csv("https://github.com/cnavarreteliz/atlas-elections-data/raw/master/data_output/Chile/2022_plebiscite_polling_station_location.csv.gz", compression='gzip')

#Merge de ambos database (Resultados eleccionarios)
data = pd.merge(df, df_location, on="polling_id")

#Importar database desde github (Polarización detallado por región y comuna)
df_ep_r = pd.read_csv("https://github.com/cnavarreteliz/atlas-elections-data/raw/master/data_curated/Chile/antagonism_2022_region_plebiscite.csv.gz", compression='gzip')
df_ep_c = pd.read_csv("https://github.com/cnavarreteliz/atlas-elections-data/raw/master/data_curated/Chile/antagonism_2022_commune_plebiscite.csv.gz", compression='gzip')

#Merge datos de polarización región
data = pd.merge(data, df_ep_r, on='region', how='left')

#Merge datos de polarización comuna
data = pd.merge(data, df_ep_c, on='commune', how='left')

#Eliminar filas con votos nulos y/o blancos
data = data[data['flag_candidates'] != 0]

#Renombrando columnas por región (r) y comunas (c)
data = data.rename(columns={
    "candidate_x": "candidate",
    "candidate_y": "candidate_r",
    "antagonism_x": "antagonism_r",
    "type_x": "type_r",
    "candidate": "candidate_c",
    "antagonism_y": "antagonism_c",
    "type_y": "type_c"
})

#Filtrar tipo de indicador en solo EP para región y comuna
data = data[(data['type_r'] == 'EP') & (data['type_c'] == 'EP')]

display (data)
# Out:
#                                                 polling_id candidate  value  \
# 10       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 11       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 14       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 15       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 26       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   RECHAZO    252
# ...                                                    ...       ...    ...
# 2462159  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   APRUEBO     99
# 2462170  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462171  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462174  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462175  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
#
#              rate  rank  flag_candidates  region_id           region  \
# 10       0.260997   2.0                1          1      DE TARAPACA
# 11       0.260997   2.0                1          1      DE TARAPACA
# 14       0.260997   2.0                1          1      DE TARAPACA
# 15       0.260997   2.0                1          1      DE TARAPACA
# 26       0.739003   1.0                1          1      DE TARAPACA
# ...           ...   ...              ...        ...              ...
# 2462159  0.322476   2.0                1          9  DE LA ARAUCANIA
# 2462170  0.677524   1.0                1          9  DE LA ARAUCANIA
# 2462171  0.677524   1.0                1          9  DE LA ARAUCANIA
# 2462174  0.677524   1.0                1          9  DE LA ARAUCANIA
# 2462175  0.677524   1.0                1          9  DE LA ARAUCANIA
#
#                senatorial_constituency     district        commune  \
# 10        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ALTO HOSPICIO
# 11        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ALTO HOSPICIO
# 14        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ALTO HOSPICIO
# 15        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ALTO HOSPICIO
# 26        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ALTO HOSPICIO
# ...                                ...          ...            ...
# 2462159  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23     VILLARRICA
# 2462170  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23     VILLARRICA
# 2462171  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23     VILLARRICA
# 2462174  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23     VILLARRICA
# 2462175  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23     VILLARRICA
#
#         electoral_district                            polling_place  \
# 10           ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 11           ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 14           ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 15           ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 26           ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# ...                    ...                                      ...
# 2462159             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462170             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462171             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462174             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462175             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
#
#          polling_station candidate_r  antagonism_r type_r candidate_c  \
# 10                    63     APRUEBO      0.045277     EP     APRUEBO
# 11                    63     APRUEBO      0.045277     EP     RECHAZO
# 14                    63     RECHAZO      0.047145     EP     APRUEBO
# 15                    63     RECHAZO      0.047145     EP     RECHAZO
# 26                    63     APRUEBO      0.045277     EP     APRUEBO
# ...                  ...         ...           ...    ...         ...
# 2462159                6     RECHAZO      0.048832     EP     RECHAZO
# 2462170                6     APRUEBO      0.051007     EP     APRUEBO
# 2462171                6     APRUEBO      0.051007     EP     RECHAZO
# 2462174                6     RECHAZO      0.048832     EP     APRUEBO
# 2462175                6     RECHAZO      0.048832     EP     RECHAZO
#
#          antagonism_c type_c
# 10           0.031195     EP
# 11           0.026345     EP
# 14           0.031195     EP
# 15           0.026345     EP
# 26           0.031195     EP
# ...               ...    ...
# 2462159      0.034306     EP
# 2462170      0.036796     EP
# 2462171      0.034306     EP
# 2462174      0.036796     EP
# 2462175      0.034306     EP
#
# [307776 rows x 20 columns]

# %%
# Agrupar regiones por Zonas de Chile
condiciones = [
    data['region_id'].isin([15, 1, 2]),  # Norte Grande
    data['region_id'].isin([3, 4]),      # Norte Chico
    data['region_id'].isin([5, 13, 6, 7, 16, 8]),  # Zona Central
    data['region_id'].isin([9, 14, 10]),  # Zona Sur
    data['region_id'].isin([11, 12])     # Zona Austral
]

# Definir los valores correspondientes a cada condición
valores = [
    "Norte Grande",
    "Norte Chico",
    "Zona Central",
    "Zona Sur",
    "Zona Austral"
]

# Crear la columna 'zona' utilizando np.select
data['zona'] = np.select(condiciones, valores)

# Mostrar las primeras filas del DataFrame con la nueva columna 'zona'
display(data.head())
# Out:
# <ipython-input-33-167bbe3710af>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['zona'] = np.select(condiciones, valores)
#                                            polling_id candidate  value  \
# 10  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 11  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 14  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 15  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 26  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   RECHAZO    252
#
#         rate  rank  flag_candidates  region_id       region  \
# 10  0.260997   2.0                1          1  DE TARAPACA
# 11  0.260997   2.0                1          1  DE TARAPACA
# 14  0.260997   2.0                1          1  DE TARAPACA
# 15  0.260997   2.0                1          1  DE TARAPACA
# 26  0.739003   1.0                1          1  DE TARAPACA
#
#          senatorial_constituency    district  ... electoral_district  \
# 10  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2  ...      ALTO HOSPICIO
# 11  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2  ...      ALTO HOSPICIO
# 14  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2  ...      ALTO HOSPICIO
# 15  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2  ...      ALTO HOSPICIO
# 26  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2  ...      ALTO HOSPICIO
#
#                               polling_place polling_station  candidate_r  \
# 10  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      APRUEBO
# 11  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      APRUEBO
# 14  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      RECHAZO
# 15  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      RECHAZO
# 26  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      APRUEBO
#
#    antagonism_r  type_r candidate_c antagonism_c  type_c          zona
# 10     0.045277      EP     APRUEBO     0.031195      EP  Norte Grande
# 11     0.045277      EP     RECHAZO     0.026345      EP  Norte Grande
# 14     0.047145      EP     APRUEBO     0.031195      EP  Norte Grande
# 15     0.047145      EP     RECHAZO     0.026345      EP  Norte Grande
# 26     0.045277      EP     APRUEBO     0.031195      EP  Norte Grande
#
# [5 rows x 21 columns]

# %%
data.nunique()
# Out:
# polling_id                 38472
# candidate                      2
# value                        338
# rate                       21431
# rank                           2
# flag_candidates                1
# region_id                     16
# region                        16
# senatorial_constituency       16
# district                      28
# commune                      346
# electoral_district           676
# polling_place               2755
# polling_station              756
# candidate_r                    2
# antagonism_r                  32
# type_r                         1
# candidate_c                    2
# antagonism_c                 691
# type_c                         1
# zona                           5
# dtype: int64

# %%
display(data)
# Out:
#                                                 polling_id candidate  value  \
# 10       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 11       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 14       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 15       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 26       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   RECHAZO    252
# ...                                                    ...       ...    ...
# 2462159  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   APRUEBO     99
# 2462170  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462171  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462174  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462175  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
#
#              rate  rank  flag_candidates  region_id           region  \
# 10       0.260997   2.0                1          1      DE TARAPACA
# 11       0.260997   2.0                1          1      DE TARAPACA
# 14       0.260997   2.0                1          1      DE TARAPACA
# 15       0.260997   2.0                1          1      DE TARAPACA
# 26       0.739003   1.0                1          1      DE TARAPACA
# ...           ...   ...              ...        ...              ...
# 2462159  0.322476   2.0                1          9  DE LA ARAUCANIA
# 2462170  0.677524   1.0                1          9  DE LA ARAUCANIA
# 2462171  0.677524   1.0                1          9  DE LA ARAUCANIA
# 2462174  0.677524   1.0                1          9  DE LA ARAUCANIA
# 2462175  0.677524   1.0                1          9  DE LA ARAUCANIA
#
#                senatorial_constituency     district  ... electoral_district  \
# 10        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ...      ALTO HOSPICIO
# 11        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ...      ALTO HOSPICIO
# 14        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ...      ALTO HOSPICIO
# 15        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ...      ALTO HOSPICIO
# 26        CIRCUNSCRIPCION SENATORIAL 2   DISTRITO 2  ...      ALTO HOSPICIO
# ...                                ...          ...  ...                ...
# 2462159  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23  ...             ÑANCUL
# 2462170  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23  ...             ÑANCUL
# 2462171  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23  ...             ÑANCUL
# 2462174  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23  ...             ÑANCUL
# 2462175  CIRCUNSCRIPCION SENATORIAL 11  DISTRITO 23  ...             ÑANCUL
#
#                                    polling_place polling_station  candidate_r  \
# 10       ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      APRUEBO
# 11       ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      APRUEBO
# 14       ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      RECHAZO
# 15       ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      RECHAZO
# 26       ANEXO DE COLEGIO SAN ANTONIO DE MATILLA              63      APRUEBO
# ...                                          ...             ...          ...
# 2462159                 ESCUELA VOIPIR DE ÑANCUL               6      RECHAZO
# 2462170                 ESCUELA VOIPIR DE ÑANCUL               6      APRUEBO
# 2462171                 ESCUELA VOIPIR DE ÑANCUL               6      APRUEBO
# 2462174                 ESCUELA VOIPIR DE ÑANCUL               6      RECHAZO
# 2462175                 ESCUELA VOIPIR DE ÑANCUL               6      RECHAZO
#
#         antagonism_r  type_r candidate_c antagonism_c  type_c          zona
# 10          0.045277      EP     APRUEBO     0.031195      EP  Norte Grande
# 11          0.045277      EP     RECHAZO     0.026345      EP  Norte Grande
# 14          0.047145      EP     APRUEBO     0.031195      EP  Norte Grande
# 15          0.047145      EP     RECHAZO     0.026345      EP  Norte Grande
# 26          0.045277      EP     APRUEBO     0.031195      EP  Norte Grande
# ...              ...     ...         ...          ...     ...           ...
# 2462159     0.048832      EP     RECHAZO     0.034306      EP      Zona Sur
# 2462170     0.051007      EP     APRUEBO     0.036796      EP      Zona Sur
# 2462171     0.051007      EP     RECHAZO     0.034306      EP      Zona Sur
# 2462174     0.048832      EP     APRUEBO     0.036796      EP      Zona Sur
# 2462175     0.048832      EP     RECHAZO     0.034306      EP      Zona Sur
#
# [307776 rows x 21 columns]

# %% [markdown]
# ##Ratios por sector

# %% [markdown]
# ###Ejemplo

# %%
#Creación columna "rate_z" para ratios de resultados electorales por zona
data['rate_z'] = data.groupby(['zona', 'candidate'])['value'].transform('sum') / data.groupby('zona')['value'].transform('sum') * 100

# Redondear la columna 'rate_z' a dos decimales
data['rate_z'] = data['rate_z'].round(2)

# Mover 'rate_z' a la derecha de 'value'
columnas = list(data.columns)
indice_value = columnas.index('value')
indice_rate_z = columnas.index('rate_z')
columnas.insert(indice_value + 1, columnas.pop(indice_rate_z))
data = data[columnas]

# %%
#Creación columna "rate_r" para ratios de resultados electorales por región
data['rate_r'] = data.groupby(['region', 'candidate'])['value'].transform('sum') / data.groupby('region')['value'].transform('sum') * 100

# Redondear la columna 'rate_r' a dos decimales
data['rate_r'] = data['rate_r'].round(2)

# Mover 'rate_r' a la derecha de 'rate_z'
columnas = list(data.columns)
indice_rate_z = columnas.index('rate_z')
indice_rate_r = columnas.index('rate_r')
columnas.insert(indice_rate_z + 1, columnas.pop(indice_rate_r))
data = data[columnas]

# %%
# Crear una nueva columna 'rate_c' para ratios de resultados electorales por comuna
data['rate_c'] = data.groupby(['commune', 'candidate'])['value'].transform('sum') / data.groupby('commune')['value'].transform('sum') * 100

# Redondear la columna 'rate_r' a dos decimales
data['rate_c'] = data['rate_c'].round(2)

# Mover 'rate_r' a la derecha de 'value'
columnas = list(data.columns)
indice_rate_r = columnas.index('rate_r')
indice_rate_c = columnas.index('rate_c')
columnas.insert(indice_rate_r + 1, columnas.pop(indice_rate_c))
data = data[columnas]

# Muestra las primeras filas del DataFrame con la nueva columna 'rate_r' a la derecha de 'value'
display(data.head())
# Out:
#                                            polling_id candidate  value  \
# 10  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 11  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 14  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 15  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 26  1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   RECHAZO    252
#
#     rate_z  rate_r  rate_c      rate  rank  flag_candidates  region_id  ...  \
# 10   34.66   31.71    27.6  0.260997   2.0                1          1  ...
# 11   34.66   31.71    27.6  0.260997   2.0                1          1  ...
# 14   34.66   31.71    27.6  0.260997   2.0                1          1  ...
# 15   34.66   31.71    27.6  0.260997   2.0                1          1  ...
# 26   65.34   68.29    72.4  0.739003   1.0                1          1  ...
#
#    electoral_district                            polling_place  \
# 10      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 11      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 14      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 15      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 26      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
#
#    polling_station candidate_r antagonism_r type_r  candidate_c antagonism_c  \
# 10              63     APRUEBO     0.045277     EP      APRUEBO     0.031195
# 11              63     APRUEBO     0.045277     EP      RECHAZO     0.026345
# 14              63     RECHAZO     0.047145     EP      APRUEBO     0.031195
# 15              63     RECHAZO     0.047145     EP      RECHAZO     0.026345
# 26              63     APRUEBO     0.045277     EP      APRUEBO     0.031195
#
#     type_c          zona
# 10      EP  Norte Grande
# 11      EP  Norte Grande
# 14      EP  Norte Grande
# 15      EP  Norte Grande
# 26      EP  Norte Grande
#
# [5 rows x 24 columns]

# %% [markdown]
# #Descripción

# %%
data_region = data[['region_id', 'region']].drop_duplicates()
display(data_region)
# Out:
#          region_id                                        region
# 10               1                                   DE TARAPACA
# 42058           10                                  DE LOS LAGOS
# 167882          11  DE AYSEN DEL GENERAL CARLOS IBAÑEZ DEL CAMPO
# 184586          12       DE MAGALLANES Y DE LA ANTARTICA CHILENA
# 210506          13                     METROPOLITANA DE SANTIAGO
# 1160522         14                                   DE LOS RIOS
# 1219530         15                         DE ARICA Y PARINACOTA
# 1250634         16                                      DE ÑUBLE
# 1321674          2                                DE ANTOFAGASTA
# 1400074          3                                    DE ATACAMA
# 1439562          4                                   DE COQUIMBO
# 1544522          5                                 DE VALPARAISO
# 1814282          6     DEL LIBERTADOR GENERAL BERNARDO O'HIGGINS
# 1943306          7                                     DEL MAULE
# 2094026          8                                    DEL BIOBIO
# 2315210          9                               DE LA ARAUCANIA

# %%
display(data)
# Out:
#                                                 polling_id candidate  value  \
# 10       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 11       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 14       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 15       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   APRUEBO     89
# 26       1-CIRCUNSCRIPCION SENATORIAL 2-DISTRITO 2-ALTO...   RECHAZO    252
# ...                                                    ...       ...    ...
# 2462159  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   APRUEBO     99
# 2462170  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462171  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462174  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
# 2462175  9-CIRCUNSCRIPCION SENATORIAL 11-DISTRITO 23-VI...   RECHAZO    208
#
#          rate_z  rate_r  rate_c      rate  rank  flag_candidates  region_id  \
# 10        34.66   31.71   27.60  0.260997   2.0                1          1
# 11        34.66   31.71   27.60  0.260997   2.0                1          1
# 14        34.66   31.71   27.60  0.260997   2.0                1          1
# 15        34.66   31.71   27.60  0.260997   2.0                1          1
# 26        65.34   68.29   72.40  0.739003   1.0                1          1
# ...         ...     ...     ...       ...   ...              ...        ...
# 2462159   29.00   26.20   30.21  0.322476   2.0                1          9
# 2462170   71.00   73.80   69.79  0.677524   1.0                1          9
# 2462171   71.00   73.80   69.79  0.677524   1.0                1          9
# 2462174   71.00   73.80   69.79  0.677524   1.0                1          9
# 2462175   71.00   73.80   69.79  0.677524   1.0                1          9
#
#          ... electoral_district                            polling_place  \
# 10       ...      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 11       ...      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 14       ...      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 15       ...      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# 26       ...      ALTO HOSPICIO  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA
# ...      ...                ...                                      ...
# 2462159  ...             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462170  ...             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462171  ...             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462174  ...             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
# 2462175  ...             ÑANCUL                 ESCUELA VOIPIR DE ÑANCUL
#
#         polling_station candidate_r antagonism_r type_r  candidate_c  \
# 10                   63     APRUEBO     0.045277     EP      APRUEBO
# 11                   63     APRUEBO     0.045277     EP      RECHAZO
# 14                   63     RECHAZO     0.047145     EP      APRUEBO
# 15                   63     RECHAZO     0.047145     EP      RECHAZO
# 26                   63     APRUEBO     0.045277     EP      APRUEBO
# ...                 ...         ...          ...    ...          ...
# 2462159               6     RECHAZO     0.048832     EP      RECHAZO
# 2462170               6     APRUEBO     0.051007     EP      APRUEBO
# 2462171               6     APRUEBO     0.051007     EP      RECHAZO
# 2462174               6     RECHAZO     0.048832     EP      APRUEBO
# 2462175               6     RECHAZO     0.048832     EP      RECHAZO
#
#         antagonism_c  type_c          zona
# 10          0.031195      EP  Norte Grande
# 11          0.026345      EP  Norte Grande
# 14          0.031195      EP  Norte Grande
# 15          0.026345      EP  Norte Grande
# 26          0.031195      EP  Norte Grande
# ...              ...     ...           ...
# 2462159     0.034306      EP      Zona Sur
# 2462170     0.036796      EP      Zona Sur
# 2462171     0.034306      EP      Zona Sur
# 2462174     0.036796      EP      Zona Sur
# 2462175     0.034306      EP      Zona Sur
#
# [307776 rows x 24 columns]

# %% [markdown]
# #Solo Comuna

# %%
#Filtro database
df1 = data[["region_id", "commune", "candidate_c", "antagonism_c"]].copy()
df1 = df1.rename(columns={"commune": "Comuna"})

#----------------------------------------------------------------------------------------------------------------
# Creamos dummies 'pol_apruebo' y 'pol_rechazo' con valores iniciales de 0
df1['pol_apruebo'] = 0
df1['pol_rechazo'] = 0

# Actualizamos los valores de las columnas según las condiciones especificadas
df1.loc[df1['candidate_c'] == 'APRUEBO', 'pol_apruebo'] = df1.loc[df1['candidate_c'] == 'APRUEBO', 'antagonism_c']
df1.loc[df1['candidate_c'] == 'RECHAZO', 'pol_rechazo'] = df1.loc[df1['candidate_c'] == 'RECHAZO', 'antagonism_c']

# Eliminamos las columnas 'candidate_c' y 'antagonism_c' si ya no son necesarias
# df1.drop(['candidate_c', 'antagonism_c'], axis=1, inplace=True)

# Si deseas mantener solo las columnas originales y las dos nuevas columnas
df1 = df1[['Comuna', 'region_id', 'pol_apruebo', 'pol_rechazo']]

#----------------------------------------------------------------------------------------------------------------
#Agrupamos en una fila por Comuna
df1 = df1.groupby('Comuna').agg({'pol_apruebo': 'max', 'pol_rechazo': 'max'}).reset_index()

# Reemplazamos los valores 0 por la información de la columna correspondiente
df1['pol_apruebo'] = df1.apply(lambda row: row['pol_rechazo'] if row['pol_apruebo'] == 0 else row['pol_apruebo'], axis=1)
df1['pol_rechazo'] = df1.apply(lambda row: row['pol_apruebo'] if row['pol_rechazo'] == 0 else row['pol_rechazo'], axis=1)

#-----------------------------------------------------------------------------------------------------------------
#Merge con region_id
df1 = df1.rename(columns={"Comuna": "commune"})
df1 = pd.merge(df1, data[['commune', 'region_id']], on='commune', how='left')

#-----------------------------------------------------------------------------------------------------------------
#Rename comuna
df1 = df1.rename(columns={"commune": "Comuna"})

# %% [markdown]
# #Exportar

# %%
#Exportar .csv
df1.to_csv('Plebiscito_Salida_2022.csv', index=False)
